# %% [markdown]
# ## Exercices d'entrainement

# %% [markdown]
# Les exercices de cette section NE SONT PAS NOTÉS. Ils servent d’entraînement pour manipuler les bases de la syntaxe Python abordées lors de la session précédente.

# %% [markdown]
# Si vous avez besoin d'autres rappels sur la syntaxe ou que vous souhaitez approfondir un peu plus les bases de Python, vous pouvez aller sur le site de w3schools, notamment la section Exercices: https://www.w3schools.com/python/exercise.asp

# %% [markdown]
# 1 - Écrire une fonction `is_even_or_odd()` qui reçoit un nombre `n` entier positif et qui affiche `PAIR` s'il est divisible par 2, `IMPAIR` sinon.

# %% [markdown]
# 2 - Écrire une fonction `calculator()` qui reçoit deux nombres: `nb1` et `nb2`, et un opérateur arithmétique sous forme de chaine de caractères: `"+"`, `"-"`, `"*"` ou `"/"`. Cette fonction renvoie le résultat de l'opération: `nb1` `opérateur` `nb2`
#
# Exemple: si on envoie 5, 6 et "*", la fonction calcule 5*6 et renvoie 30.

# %% [markdown]
# 3 - Écrire une fonction `triple_list()` qui reçoit un nombre `n` et qui affiche une suite de 6 nombres dont le premier est n et chaque nombre suivant est égal au triple du nombre précédent.
#
# Exemple: si on envoie 2, la fonction affiche 2, 6, 18, 54, 162, 486.

# %% [markdown]
# 4 - Écrire une fonction `list_ends()` qui reçoit une liste de nombres et qui renvoie une nouvelle liste composée uniquement du premier et du dernier élément de la liste reçue.
#
# Exemple: si on envoie [3, 5, 8, 1, 24], la fonction renvoie [3, 24].

# %% [markdown]
# 5 - Écrire une fonction `min_max_moy()` qui reçoit une liste de nombres entiers et qui renvoie le minimum, le maximum et la moyenne de cette liste sous la forme d'un tuple composé des trois résultats. Pour rappel la moyenne est définie comme étant la somme de la liste divisée par le nombre d'éléments de la liste.
#
# Exemple: si on envoie [10, 18, 14, 20, 12, 16], la fonction renvoie (10, 20, 15.0).

# %% [markdown]
# 6 - Écrire une fonction `is_char_in_str()` qui reçoit une lettre (chaine de longueur 1) et une chaine de caractères. La fonction détermine si la chaine contient ou non la lettre et renvoie un booléen.
#
# Exemple: si on envoie "e" et "Hello world!", la fonction renvoie True.

# %% [markdown]
# 7 - Écrire une fonction `how_many_char()` similaire à l'exercice 6 mais qui indique cette fois le nombre de fois où la lettre apparait dans la chaine de caractères, on parle du nombre d'occurences.
#
# Exemple: si on envoie "o" et "Hello world!", la fonction renvoie 2.

# %% [markdown]
# 8 - Écrire une fonction `reverse_str()` qui recopie une chaîne de caractères dans une nouvelle variable en l'inversant.
#
# Exemple: si on envoie "Hello world!", la fonction renvoie "!dlrow olleH"

# %% [markdown]
# 9 - Recherche de palindrome: Écrire une fonction `is_palindromic()` qui reçoit une chaine de caractères et détermine si elle peut être lue dans les deux sens de manière identique en renvoyant un booléen.
#
# Exemple: Les mots "radar" et "kayak" sont des palindromes.

# %% [markdown]
# 10 - Écrire une fonction `carpet()` qui, recevant une taille `n` en paramètre, affiche un tapis de n+1 lignes par n+1 colonnes traversé par une diagonale vide.
#
# Exemple: si on envoie 10, la fonction affiche :
# ```
# +-----------+
# |########## |
# |######### #|
# |######## ##|
# |####### ###|
# |###### ####|
# |##### #####|
# |#### ######|
# |### #######|
# |## ########|
# |# #########|
# | ##########|
# +-----------+
# ```

# %% [markdown]
# ## Exercice noté
#
# L'exercice de cette section __EST NOTÉ__. Il faut remplir les cellules sous les questions avec votre code puis le notebook est à rendre sur MyGES dans l'onglet Travaux Pratiques avant le début du prochain cours.
#
# Consigne: Répondre à chaque question par du code de manière à pouvoir exécuter le notebook sans erreur depuis le début. Écrire directement le résultat d'une question n'est pas accepté, il faut écrire le code ou la fonction qui calcule ce résultat. Chaque question vaut un point.

# %% [markdown]
# Voici une liste de 15 chiens qui ont participé à une compétition. Pour chacun on retrouve: leur nom, leur score en épreuve d'Agility, leur score en épreuve de Jumping, leur année de naissance et leur race. Aucune connaissance dans ce domaine n'est requise pour résoudre cet exercice.

# %%
chiens = [
    {"nom": "Nala", "note_agility": 15, "note_jumping": 14, "naissance": 2020, "race": "Welsh Corgi"},
    {"nom": "Tempete", "note_agility": 12, "note_jumping": 13, "naissance": 2018, "race": "Berger des Shetland"},
    {"nom": "Lucky", "note_agility": 18, "note_jumping": 17, "naissance": 2021, "race": "Berger Australien"},
    {"nom": "Snoopy", "note_agility": 13, "note_jumping": 12, "naissance": 2019, "race": "Border Collie"},
    {"nom": "Nougat", "note_agility": 13, "note_jumping": 12, "naissance": 2021, "race": "Caniche"},
    {"nom": "Merlin", "note_agility": 14, "note_jumping": 12, "naissance": 2020, "race": "Border Collie"},
    {"nom": "Laika", "note_agility": 11, "note_jumping": 9, "naissance": 2018, "race": "Berger Australien"},
    {"nom": "Noisette", "note_agility": 13, "note_jumping": 11, "naissance": 2019, "race": "Welsh Corgi"},
    {"nom": "Jazz", "note_agility": 17, "note_jumping": 10, "naissance": 2018, "race": "Berger Australien"},
    {"nom": "Simba", "note_agility": 13, "note_jumping": 9, "naissance": 2020, "race": "Caniche"},
    {"nom": "Newton", "note_agility": 10, "note_jumping": 10, "naissance": 2018, "race": "Berger des Shetland"},
    {"nom": "Kiwi", "note_agility": 18, "note_jumping": 13, "naissance": 2021, "race": "Border Collie"},
    {"nom": "Oslo", "note_agility": 19, "note_jumping": 8, "naissance": 2021, "race": "Border Collie"},
    {"nom": "Sushi", "note_agility": 19, "note_jumping": 15, "naissance": 2020, "race": "Border Collie"},
    {"nom": "Happy", "note_agility": 13, "note_jumping": 8, "naissance": 2021, "race": "Berger Australien"}
]

# %% [markdown]
# 1 - Qui a la meilleure note et la moins bonne note en épreuve d'Agility ? Écrire une fonction qui affiche le résultat.

# %% [markdown]
# 2 - Quelle est la moyenne globale de l'épreuve de Jumping ? Écrire une fonction qui affiche le résultat.

# %% [markdown]
# 3 - Quelle est la race qui apparait le plus souvent ? Écrire une fonction qui affiche le résultat.

# %% [markdown]
# 4 - Lister toutes les races de chiens présents dans la compétition. Écrire une fonction qui affiche le résultat.

# %% [markdown]
# 5 - Lister les noms des chiens nés après 2019 et ayant au moins une de ses deux notes supérieure ou égale à 15. Écrire une fonction qui affiche le résultat.

# %% [markdown]
# 6 - Deux nouveaux chiens arrivent dans la compétition:
# ```
# {"nom": "Rocky", "note_agility": 16, "note_jumping": 18, "naissance": 2020, "race": "Caniche"}
# et
# {"nom": "Oreo", "note_agility": 10, "note_jumping": 13, "naissance": 2017, "race": "Berger Allemand"}
# ```
# Ajouter les nouveaux chiens à la liste puis répondre à nouveau aux questions 1 à 5.

# %% [markdown]
# 7 - Quel est le classement de Rocky le nouveau chien, pour chacune des deux épreuves ? Écrire une fonction qui affiche le résultat.

# %% [markdown]
# 8 - Quelle race de chien a la moyenne la plus élevée en Agility ? Écrire une fonction qui affiche le résultat.
